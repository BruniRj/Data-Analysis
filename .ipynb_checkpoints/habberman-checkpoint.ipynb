# %%
# Mini-projet : Nettoie le dataset "Haberman" (Kaggle)
# Télécharge haberman.csv

# Supprime les lignes avec valeurs manquantes (s'il y en a)

# Ajoute une colonne "age_group" : "<50", "50-65", ">65"

# Sauvegarde le dataframe nettoyé en haberman_clean.csv
